# %% [markdown]
# # Trabajo de Redes Sociales: Comunidades Prehistóricas y Pangea
#
# **Autores:** Raúl Fernández, Aitor Nieto, Juan Carlos Cintas, Javier Riscos
#
# ---
# ## INTRODUCCIÓN
# ### 1. ¿De qué trata el proyecto?
# En este proyecto vamos a estudiar las distribuciones de los fósiles del periodo Triásico para así no solo estudiar como se relacionaban las especies prehistóricas entre sí sino tambien para demostrar la existencia de pangea en la antiguedad.
#
# ### 2. Objetivos
# TODO
#
# ### 3. Metodología y Fundamentos Teóricos
# TODO
#
# > **Nota:** El grafo se define como un conjunto de nodos () y aristas ().
#
# ### 4. Descripción del Conjunto de Datos
# Los datos utilizados provienen de registros arqueológicos obtenidos en la pagina de [paleobiodb](https://paleobiodb.org/navigator/) en formato de CSV, utilizamos:
# * TODO
#
# ---

# %% [markdown]
# ## DESARROLLO
#
# ### 1. Descarga y tratado de datos
# Lo primero que hicimos fue descargar los datos de la fuente ya mencionada (paleobiodb) ya que es el repositório de datos sobre especies antiquísimas como las que habitaban en el Mesozoico. Descargamos el CSV completo con todos los datos de la época **Triásica** ya que fue la última etapa donde **Pangea** aún existía.
#
# Tras haber descargado el CSV realizamos **EDA intensivo** para quedarnos solo con las columnas que nos interesan; en este caso
